# %% [markdown]
# # Piyush Mehar 20BCE10065 Assignment 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Download the dataset: Dataset

# %% [markdown]
# 2. Load the dataset.

# %%
data= pd.read_csv('F:\expenship ds\sir material\\titanic.csv')

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# 3. Perform Below Visualizations

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
sns.distplot(data.age)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
plt.bar(data['sex'],data['age'])
# Out:
# <BarContainer object of 891 artists>

# %%
sns.countplot(data.survived)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
data.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# 4. Perform descriptive statistics on the dataset

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# 5. Handle the Missing values.

# %%
data.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# if we have null values in numerical column we replace it with Mean/Median
# if we have null values in categorical column e replace it with Mode

# %%
data['age'].fillna(data['age'].mean(),inplace=True)

# %%
data['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
data['embarked'].fillna('S',inplace=True)

# %%
data['embark_town'].value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
data['embark_town'].fillna('Southampton',inplace=True)

# %%
data['deck'].value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: deck, dtype: int64

# %%
data['deck'].fillna('C',inplace=True)

# %%
data.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# 6. Find the outliers and replace the outliers

# %%
data.describe(percentiles=[.25, .5, .75, .90, .95, .99])
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# 90%      1.000000    3.000000   47.000000    1.000000    2.000000   77.958300
# 95%      1.000000    3.000000   54.000000    3.000000    2.000000  112.079150
# 99%      1.000000    3.000000   65.000000    5.000000    4.000000  249.006220
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# we see that there is outlier in fare

# %%
sns.boxplot(data.fare)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fare'>

# %%
q = data["fare"].quantile(0.99)
data = data[data['fare'] < q]

# %%
data['fare'].describe(percentiles=[.25, .5, .75, .90, .95, .99])
# Out:
# count    846.000000
# mean      23.233323
# std       22.370805
# min        0.000000
# 25%        7.895800
# 50%       13.000000
# 75%       27.900000
# 90%       56.495800
# 95%       77.958300
# 99%       93.500000
# max      110.883300
# Name: fare, dtype: float64

# %% [markdown]
# 7. Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True    C  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False    C  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True    C  Southampton    no   True

# %%
data.rename(columns = {'class':'Class'}, inplace = True)

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  Class  who  \
# 0         0       3    1  22.0      1      0   7.2500         2  Third    1
# 1         1       1    0  38.0      1      0  71.2833         0  First    2
# 2         1       3    0  26.0      0      0   7.9250         2  Third    2
# 3         1       1    0  35.0      1      0  53.1000         2  First    2
# 4         0       3    1  35.0      0      0   8.0500         2  Third    1
#
#    adult_male  deck  embark_town  alive  alone
# 0           1     2  Southampton      0      0
# 1           0     2    Cherbourg      1      0
# 2           0     2  Southampton      1      1
# 3           0     2  Southampton      1      0
# 4           1     2  Southampton      0      1

# %%
data.sex=le.fit_transform(data.sex)
data.embarked=le.fit_transform(data.embarked)
data.Class=le.fit_transform(data.Class)
data.who=le.fit_transform(data.who)
data.adult_male=le.fit_transform(data.adult_male)
data.deck=le.fit_transform(data.deck)
data.alive=le.fit_transform(data.alive)
data.alone=le.fit_transform(data.alone)

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  Class  who  \
# 0         0       3    1  22.0      1      0   7.2500         2      2    1
# 1         1       1    0  38.0      1      0  71.2833         0      0    2
# 2         1       3    0  26.0      0      0   7.9250         2      2    2
# 3         1       1    0  35.0      1      0  53.1000         2      0    2
# 4         0       3    1  35.0      0      0   8.0500         2      2    1
#
#    adult_male  deck  embark_town  alive  alone
# 0           1     2  Southampton      0      0
# 1           0     2    Cherbourg      1      0
# 2           0     2  Southampton      1      1
# 3           0     2  Southampton      1      0
# 4           1     2  Southampton      0      1

# %%
data=pd.get_dummies(data,columns=['embark_town'])

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare  embarked  Class  who  \
# 0         0       3    1  22.0      1      0   7.2500         2      2    1
# 1         1       1    0  38.0      1      0  71.2833         0      0    2
# 2         1       3    0  26.0      0      0   7.9250         2      2    2
# 3         1       1    0  35.0      1      0  53.1000         2      0    2
# 4         0       3    1  35.0      0      0   8.0500         2      2    1
#
#    adult_male  deck  alive  alone  embark_town_Cherbourg  \
# 0           1     2      0      0                      0
# 1           0     2      1      0                      1
# 2           0     2      1      1                      0
# 3           0     2      1      0                      0
# 4           1     2      0      1                      0
#
#    embark_town_Queenstown  embark_town_Southampton
# 0                       0                        1
# 1                       0                        0
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# 8. Split the data into dependent and independent variables.

# %%
y=data['survived']  # Y is dependent variable(target)

# %%
x=data.drop(columns=['survived'],axis=1)  # X is independent variable or predictors

# %% [markdown]
# 9. Scale the independent variables

# %%
name=x.columns

# %%
name
# Out:
# Index(['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked', 'Class',
#        'who', 'adult_male', 'deck', 'alive', 'alone', 'embark_town_Cherbourg',
#        'embark_town_Queenstown', 'embark_town_Southampton'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
X_scaled=scale.fit_transform(x)

# %%
X_scaled
# Out:
# array([[1.        , 1.        , 0.27117366, ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 0.        , 0.4722292 , ..., 1.        , 0.        ,
#         0.        ],
#        [1.        , 0.        , 0.32143755, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [1.        , 0.        , 0.36792055, ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 1.        , 0.32143755, ..., 1.        , 0.        ,
#         0.        ],
#        [1.        , 1.        , 0.39683338, ..., 0.        , 1.        ,
#         0.        ]])

# %%
x=pd.DataFrame(X_scaled,columns=name)

# %%
x
# Out:
#      pclass  sex       age  sibsp     parch      fare  embarked  Class  who  \
# 0       1.0  1.0  0.271174  0.125  0.000000  0.065384       1.0    1.0  0.5
# 1       0.0  0.0  0.472229  0.125  0.000000  0.642868       0.0    0.0  1.0
# 2       1.0  0.0  0.321438  0.000  0.000000  0.071472       1.0    1.0  1.0
# 3       0.0  0.0  0.434531  0.125  0.000000  0.478882       1.0    0.0  1.0
# 4       1.0  1.0  0.434531  0.000  0.000000  0.072599       1.0    1.0  0.5
# ..      ...  ...       ...    ...       ...       ...       ...    ...  ...
# 841     0.5  1.0  0.334004  0.000  0.000000  0.117240       1.0    0.5  0.5
# 842     0.0  0.0  0.233476  0.000  0.000000  0.270555       1.0    0.0  1.0
# 843     1.0  0.0  0.367921  0.125  0.333333  0.211484       1.0    1.0  1.0
# 844     0.0  1.0  0.321438  0.000  0.000000  0.270555       0.0    0.0  0.5
# 845     1.0  1.0  0.396833  0.000  0.000000  0.069893       0.5    1.0  0.5
#
# ...

# %% [markdown]
# 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#      pclass  sex       age  sibsp     parch      fare  embarked  Class  who  \
# 252     0.5  0.0  0.623021  0.000  0.166667  0.234481       1.0    0.5  1.0
# 389     1.0  1.0  0.547625  0.000  0.000000  0.071472       1.0    1.0  0.5
# 503     1.0  1.0  0.208344  0.125  0.166667  0.065196       0.0    1.0  0.5
# 2       1.0  0.0  0.321438  0.000  0.000000  0.071472       1.0    1.0  1.0
# 837     1.0  0.0  0.271174  0.000  0.000000  0.094845       1.0    1.0  1.0
#
#      adult_male      deck  alive  alone  embark_town_Cherbourg  \
# 252         0.0  0.333333    1.0    0.0                    0.0
# 389         1.0  0.333333    1.0    1.0                    0.0
# 503         1.0  0.333333    0.0    0.0                    1.0
# 2           0.0  0.333333    1.0    1.0                    0.0
# 837         0.0  0.333333    0.0    1.0                    0.0
#
#      embark_town_Queenstown  embark_town_Southampton
# 252                     0.0                      1.0
# ...

# %%
X_test.head()
# Out:
#      pclass  sex       age  sibsp     parch      fare  embarked  Class  who  \
# 506     0.5  0.0  0.082684    0.0  0.333333  0.236735       1.0    0.5  0.0
# 222     0.5  1.0  0.220910    0.0  0.000000  0.117240       1.0    0.5  0.5
# 612     1.0  1.0  0.367921    0.0  0.000000  0.509507       1.0    1.0  0.5
# 730     0.5  0.0  0.710983    0.0  0.000000  0.094694       1.0    0.5  1.0
# 661     1.0  1.0  0.547625    0.0  0.000000  0.072599       1.0    1.0  0.5
#
#      adult_male      deck  alive  alone  embark_town_Cherbourg  \
# 506         0.0  0.333333    1.0    0.0                    0.0
# 222         1.0  0.333333    0.0    1.0                    0.0
# 612         1.0  0.333333    1.0    1.0                    0.0
# 730         0.0  0.666667    0.0    1.0                    0.0
# 661         1.0  0.333333    0.0    1.0                    0.0
#
#      embark_town_Queenstown  embark_town_Southampton
# 506                     0.0                      1.0
# ...

# %%
y_train
# Out:
# 259    1
# 414    1
# 532    0
# 2      1
# 882    0
#       ..
# 880    1
# 197    0
# 662    0
# 589    0
# 722    0
# Name: survived, Length: 676, dtype: int64

# %%
y_test
# Out:
# 535    1
# 228    0
# 643    1
# 772    0
# 696    0
#       ..
# 70     0
# 636    0
# 288    1
# 709    1
# 674    0
# Name: survived, Length: 170, dtype: int64
